# %%
from eralchemy import render_er
import pandas as pd
import matplotlib.pyplot as plt

# %%
## Draw from database
render_er("sqlite:///hr.db", 'erd_from_sqlite.png', mode='graph')

# %%
## Draw from database
render_er("sqlite:///hr.db", 'erd_from_sqlite.png', mode='er')

# %%
import sqlite3
con = sqlite3.connect("./hr")
con

# %%
# render_er(con, 'dsa.png')

# %% [markdown]
# ## Q2 Present a bar chart with the number of employees with the same job. Use Plotly-Dash to make your bar chart dynamic and allow the user to choose the job titles to be seen in the chart.

# %%
employees = pd.read_csv('./csv-files-for-use/EMPLOYEES.csv')
employees
# Out:
#      employ_id first_name last_name     email  phone_number   hire_date  \
# 0          100     Steven      King     SKING  515.123.4567  2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4          104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..         ...        ...       ...       ...           ...         ...
# 102        202        Pat       Fay      PFAY  603.123.6666  2005-08-17
# 103        203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 104        204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 105        205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 106        206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          job_id  salary  commission_pct  manager_id  department_id
# ...

# %%
jobs=pd.read_csv('./csv-files-for-use/JOBS.csv')
jobs
# Out:
#         job_id                        job_title  min_salary  max_salary
# 0      AD_PRES                        President       20000       40000
# 1        AD_VP    Administration Vice President       15000       30000
# 2      AD_ASST         Administration Assistant        3000        6000
# 3       FI_MGR                  Finance Manager        8200       16000
# 4   FI_ACCOUNT                       Accountant        4200        9000
# 5       AC_MGR               Accounting Manager        8200       16000
# 6   AC_ACCOUNT                Public Accountant        4200        9000
# 7       SA_MAN                    Sales Manager       10000       20000
# 8       SA_REP             Sales Representative        6000       12000
# 9       PU_MAN               Purchasing Manager        8000       15000
# 10    PU_CLERK                 Purchasing Clerk        2500        5500
# 11      ST_MAN                    Stock Manager        5500        8500
# ...

# %%
having_same_job = pd.merge(jobs,employees,how='inner', on='job_id')
having_same_job
# Out:
#       job_id                        job_title  min_salary  max_salary  \
# 0    AD_PRES                        President       20000       40000
# 1      AD_VP    Administration Vice President       15000       30000
# 2      AD_VP    Administration Vice President       15000       30000
# 3    AD_ASST         Administration Assistant        3000        6000
# 4     FI_MGR                  Finance Manager        8200       16000
# ..       ...                              ...         ...         ...
# 102  IT_PROG                       Programmer        4000       10000
# 103   MK_MAN                Marketing Manager        9000       15000
# 104   MK_REP         Marketing Representative        4000        9000
# 105   HR_REP   Human Resources Representative        4000        9000
# 106   PR_REP  Public Relations Representative        4500       10500
#
#      employ_id first_name  last_name     email  phone_number   hire_date  \
# ...

# %%
having_same_job
# Out:
#       job_id                        job_title  min_salary  max_salary  \
# 0    AD_PRES                        President       20000       40000
# 1      AD_VP    Administration Vice President       15000       30000
# 2      AD_VP    Administration Vice President       15000       30000
# 3    AD_ASST         Administration Assistant        3000        6000
# 4     FI_MGR                  Finance Manager        8200       16000
# ..       ...                              ...         ...         ...
# 102  IT_PROG                       Programmer        4000       10000
# 103   MK_MAN                Marketing Manager        9000       15000
# 104   MK_REP         Marketing Representative        4000        9000
# 105   HR_REP   Human Resources Representative        4000        9000
# 106   PR_REP  Public Relations Representative        4500       10500
#
#      employ_id first_name  last_name     email  phone_number   hire_date  \
# ...

# %%
having_same_job['job_title'].value_counts()
# Out:
# Sales Representative               30
# Shipping Clerk                     20
# Stock Clerk                        20
# Accountant                          5
# Programmer                          5
# Sales Manager                       5
# Purchasing Clerk                    5
# Stock Manager                       5
# Administration Vice President       2
# President                           1
# Human Resources Representative      1
# Marketing Representative            1
# Marketing Manager                   1
# Purchasing Manager                  1
# Public Accountant                   1
# Accounting Manager                  1
# Finance Manager                     1
# Administration Assistant            1
# Public Relations Representative     1
# Name: job_title, dtype: int64

# %%
having_same_job['job_title']=='Public M'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 102    False
# 103    False
# 104    False
# 105    False
# 106    False
# Name: job_title, Length: 107, dtype: bool

# %%
type(having_same_job['job_title'].value_counts())
# Out:
# pandas.core.series.Series

# %%
bar_dict=having_same_job['job_title'].value_counts()

# %%
data=pd.DataFrame(columns=['job_title','empolyees'])

# %%
x=[bar_dict.keys()[i] for i in range(len(bar_dict))]
heights=[bar_dict[i] for i in range(len(bar_dict))]
data['job_title']=x
data['empolyees']=heights


# heights=pd.Series(heights)
data
# Out:
#                           job_title  empolyees
# 0              Sales Representative         30
# 1                    Shipping Clerk         20
# 2                       Stock Clerk         20
# 3                        Accountant          5
# 4                        Programmer          5
# 5                     Sales Manager          5
# 6                  Purchasing Clerk          5
# 7                     Stock Manager          5
# 8     Administration Vice President          2
# 9                         President          1
# 10   Human Resources Representative          1
# 11         Marketing Representative          1
# 12                Marketing Manager          1
# 13               Purchasing Manager          1
# 14                Public Accountant          1
# 15               Accounting Manager          1
# 16                  Finance Manager          1
# 17         Administration Assistant          1
# 18  Public Relations Representative          1

# %%
plt.bar(x, height=heights)
# bar_dict.keys()[0]
# Out:
# <BarContainer object of 19 artists>

# %%
mask = having_same_job['job_title'] == job
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 mask = having_same_job['job_title'] == job
#
# NameError: name 'job' is not defined
